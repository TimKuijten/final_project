# %%
import pandas as pd

# %%
import pandas as pd

data = {'Date': ['October 2011', 'November 2014', 'May 2016', 'February 2011', 'April 2014', 'June 2020', 'November 2022', 'January 2021', 'October 2014', 'January 2018', 'July 2022', 'December 2016'],
        'Name': ['Siri', 'Alexa', 'Google Assistant', 'IBM Watson', 'Microsoft Cortana', 'ChatGPT', 'ChatGPT', 'Dall-E', 'Tesla Autopilot', 'Amazon Go', 'MidJourney', 'Waymo'],
        'Description': ["Apple's virtual assistant that uses natural language processing to answer questions and perform tasks.",
                        "Amazon's virtual assistant that uses natural language processing to answer questions, perform tasks, and control smart home devices.",
                        "Google's virtual assistant that uses natural language processing to answer questions, perform tasks, and control smart home devices.",
                        "IBM's AI platform that uses natural language processing and machine learning to analyze data, generate insights, and solve complex problems.",
                        "Microsoft's virtual assistant that uses natural language processing to answer questions and perform tasks.",
                        "A conversational AI model developed by OpenAI that can answer questions and generate human-like text.",
                        "The open beta of a conversational AI model developed by OpenAI that can answer questions and generate human-like text.",
                        "An AI model developed by OpenAI that can generate images from textual descriptions.",
                        "Tesla's autonomous driving system that uses computer vision and machine learning to navigate roads and avoid obstacles.",
                        "Amazon's cashier-less convenience stores that use computer vision and machine learning to track what customers purchase and charge them automatically.",
                        "A conversational AI platform that uses natural language processing to provide personalized customer support and generate insights for businesses.",
                        "Waymo is a self-driving car company that was originally a project of Google. It uses a combination of sensors, cameras, and AI algorithms to navigate roads and safely transport passengers to their destinations."]
       }

df_ai_products = pd.DataFrame(data)
print(df_ai_products)
# Out:
#              Date               Name  \
# 0    October 2011               Siri
# 1   November 2014              Alexa
# 2        May 2016   Google Assistant
# 3   February 2011         IBM Watson
# 4      April 2014  Microsoft Cortana
# 5       June 2020            ChatGPT
# 6   November 2022            ChatGPT
# 7    January 2021             Dall-E
# 8    October 2014    Tesla Autopilot
# 9    January 2018          Amazon Go
# 10      July 2022         MidJourney
# 11  December 2016              Waymo
#
#                                           Description
# 0   Apple's virtual assistant that uses natural la...
# 1   Amazon's virtual assistant that uses natural l...
# 2   Google's virtual assistant that uses natural l...
# 3   IBM's AI platform that uses natural language p...
# 4   Microsoft's virtual assistant that uses natura...
# 5   A conversational AI model developed by OpenAI ...
# 6   The open beta of a conversational AI model dev...
# ...

# %%
df_ai_products
# Out:
#              Date               Name  \
# 0    October 2011               Siri
# 1   November 2014              Alexa
# 2        May 2016   Google Assistant
# 3   February 2011         IBM Watson
# 4      April 2014  Microsoft Cortana
# 5       June 2020            ChatGPT
# 6   November 2022            ChatGPT
# 7    January 2021             Dall-E
# 8    October 2014    Tesla Autopilot
# 9    January 2018          Amazon Go
# 10      July 2022         MidJourney
# 11  December 2016              Waymo
#
#                                           Description
# 0   Apple's virtual assistant that uses natural la...
# 1   Amazon's virtual assistant that uses natural l...
# 2   Google's virtual assistant that uses natural l...
# 3   IBM's AI platform that uses natural language p...
# 4   Microsoft's virtual assistant that uses natura...
# 5   A conversational AI model developed by OpenAI ...
# 6   The open beta of a conversational AI model dev...
# ...

# %%
data = {'Date': ['February 2011', 'September 2012', 'January 2014', 'March 2016', 'December 2017', 'June 2018', 'June 2019', 'October 2019', 'June 2020', 'December 2020'],
        'Name': ['Watson', 'ImageNet', 'DeepMind', 'AlphaGo', 'AlphaZero', 'GPT', 'The first AI-generated drug', 'Quantum supremacy', 'GPT-3', 'AlphaFold'],
        'Description': ["IBM's Watson defeats human champions in the game of Jeopardy! and demonstrates the potential of AI in natural language processing and machine learning.",
                        'The ImageNet dataset is created, leading to significant advances in computer vision and the development of deep learning.',
                        'A British AI company, develops a neural network that learns how to play Atari games at superhuman levels.',
                        'An AI program developed by DeepMind, defeats the world champion in the game of Go, demonstrating the potential of AI in complex decision-making.',
                        'Another AI program developed by DeepMind, learns to play chess, shogi, and Go at superhuman levels without any prior knowledge or human guidance.',
                        "OpenAI's AI system, called GPT (Generative Pre-trained Transformer), is introduced and can write coherent and human-like text.",
                        'The first AI-generated drug to enter human clinical trials is developed by the British AI company Exscientia.',
                        'Google announces that its quantum computer has achieved "quantum supremacy," performing a calculation in just 200 seconds that would have taken a classical computer 10,000 years.',
                        'OpenAI\'s GPT-3 is introduced, which is the largest language model to date, with 175 billion parameters, and is capable of generating high-quality text with little input.',
                        'An AI system developed by DeepMind, solves one of the biggest challenges in biology: predicting the 3D structure of proteins with remarkable accuracy.'
                       ]}


df_ai_events = pd.DataFrame(data)
df_ai_events
# Out:
#              Date                         Name  \
# 0   February 2011                       Watson
# 1  September 2012                     ImageNet
# 2    January 2014                     DeepMind
# 3      March 2016                      AlphaGo
# 4   December 2017                    AlphaZero
# 5       June 2018                          GPT
# 6       June 2019  The first AI-generated drug
# 7    October 2019            Quantum supremacy
# 8       June 2020                        GPT-3
# 9   December 2020                    AlphaFold
#
#                                          Description
# 0  IBM's Watson defeats human champions in the ga...
# 1  The ImageNet dataset is created, leading to si...
# 2  A British AI company, develops a neural networ...
# 3  An AI program developed by DeepMind, defeats t...
# 4  Another AI program developed by DeepMind, lear...
# 5  OpenAI's AI system, called GPT (Generative Pre...
# 6  The first AI-generated drug to enter human cli...
# ...

# %%
df_ai_products.to_csv('./ai_data/df_ai_products', index=False)
df_ai_events.to_csv('./ai_data/df_ai_events', index=False)
